# %% [markdown]
# # Overview

# %% [markdown]
# ![Overview2%20%281%29%20(1).jpg](attachment:Overview2%20%281%29%20(1).jpg)

# %% [markdown]
# ![Scores6%20%281%29.jpg](attachment:Scores6%20%281%29.jpg)

# %% [markdown]
# ### Data Source:
# https://www.kaggle.com/datasets/corrieaar/apartment-rental-offers-in-germany

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('immo_data.csv')

# %%
data.columns
# Out:
# Index(['regio1', 'serviceCharge', 'heatingType', 'telekomTvOffer',
#        'telekomHybridUploadSpeed', 'newlyConst', 'balcony', 'picturecount',
#        'pricetrend', 'telekomUploadSpeed', 'totalRent', 'yearConstructed',
#        'scoutId', 'noParkSpaces', 'firingTypes', 'hasKitchen', 'geo_bln',
#        'cellar', 'yearConstructedRange', 'baseRent', 'houseNumber',
#        'livingSpace', 'geo_krs', 'condition', 'interiorQual', 'petsAllowed',
#        'street', 'streetPlain', 'lift', 'baseRentRange', 'typeOfFlat',
#        'geo_plz', 'noRooms', 'thermalChar', 'floor', 'numberOfFloors',
#        'noRoomsRange', 'garden', 'livingSpaceRange', 'regio2', 'regio3',
#        'description', 'facilities', 'heatingCosts', 'energyEfficiencyClass',
#        'lastRefurbish', 'electricityBasePrice', 'electricityKwhPrice', 'date'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# regio1                           0
# serviceCharge                 6909
# heatingType                  44856
# telekomTvOffer               32619
# telekomHybridUploadSpeed    223830
# newlyConst                       0
# balcony                          0
# picturecount                     0
# pricetrend                    1832
# telekomUploadSpeed           33358
# totalRent                    40517
# yearConstructed              57045
# scoutId                          0
# noParkSpaces                175798
# firingTypes                  56964
# hasKitchen                       0
# geo_bln                          0
# cellar                           0
# yearConstructedRange         57045
# baseRent                         0
# houseNumber                  71018
# livingSpace                      0
# geo_krs                          0
# condition                    68489
# interiorQual                112665
# petsAllowed                 114573
# street                           0
# streetPlain                  71013
# lift                             0
# baseRentRange                    0
# typeOfFlat                   36614
# geo_plz                          0
# noRooms                          0
# thermalChar                 106506
# floor                        51309
# numberOfFloors               97732
# noRoomsRange                     0
# garden                           0
# livingSpaceRange                 0
# regio2                           0
# regio3                           0
# description                  19747
# facilities                   52924
# heatingCosts                183332
# energyEfficiencyClass       191063
# lastRefurbish               188139
# electricityBasePrice        222004
# electricityKwhPrice         222004
# date                             0
# dtype: int64

# %%
data.shape
# Out:
# (268850, 49)

# %%
pd.set_option('display.max_columns', None)
data.sample(n = 4)
# Out:
#                      regio1  serviceCharge       heatingType telekomTvOffer  \
# 12817   Nordrhein_Westfalen          216.0               NaN  ONE_YEAR_FREE
# 45619           Brandenburg          230.0  district_heating  ONE_YEAR_FREE
# 55314               Sachsen          110.0       gas_heating  ONE_YEAR_FREE
# 211789   Schleswig_Holstein           60.0   central_heating  ONE_YEAR_FREE
#
#         telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 12817                        NaN       False    False             7
# 45619                        NaN       False     True            23
# 55314                       10.0       False     True             5
# 211789                       NaN       False     True             8
#
#         pricetrend  telekomUploadSpeed  totalRent  yearConstructed    scoutId  \
# 12817         3.83                40.0        NaN           1962.0  114243778
# 45619         5.19                40.0     2264.0           1876.0  114614613
# 55314         2.14                 2.4      850.0           1973.0  115667540
# 211789        3.17                40.0      600.0           1976.0  110344904
#
#         noParkSpaces        firingTypes  hasKitchen              geo_bln  \
# 12817            NaN                NaN       False  Nordrhein_Westfalen
# 45619            NaN                NaN        True          Brandenburg
# 55314            NaN                gas        True              Sachsen
# 211789           NaN  natural_gas_heavy        True   Schleswig_Holstein
#
#         cellar  yearConstructedRange  baseRent houseNumber  livingSpace  \
# 12817    False                   2.0     409.0           7         64.0
# 45619    False                   1.0    1704.0          17        142.0
# 55314     True                   3.0     590.0          18        119.0
# 211789    True                   3.0     450.0          19         75.0
#
#                             geo_krs        condition interiorQual petsAllowed  \
# 12817                  Borken_Kreis              NaN          NaN         NaN
# 45619                       Potsdam      refurbished          NaN         NaN
# 55314                 Görlitz_Kreis      refurbished       normal  negotiable
# 211789  Rendsburg_Eckernförde_Kreis  fully_renovated       normal  negotiable
#
#                               street             streetPlain   lift  \
# 12817    Kurt-Ackermann-Stra&szlig;e   Kurt-Ackermann-Straße  False
# 45619              Helene-Lange-Str.       Helene-Lange-Str.  False
# 55314                     Oberer Weg              Oberer_Weg  False
# 211789  Johannes Brahms Stra&szlig;e  Johannes_Brahms_Straße  False
#
#         baseRentRange           typeOfFlat  geo_plz  noRooms  thermalChar  \
# 12817               3          roof_storey    48599      4.0        205.9
# 45619               8  raised_ground_floor    14469      4.0          NaN
# 55314               4            apartment     2894      6.0        106.0
# 211789              3            apartment    24768      3.0        119.0
#
#         floor  numberOfFloors  noRoomsRange  garden  livingSpaceRange  \
# 12817     2.0             2.0             4   False                 3
# 45619     NaN             NaN             4   False                 6
# 55314     2.0             4.0             5   False                 5
# 211789    3.0             4.0             3   False                 3
#
#                              regio2                   regio3  \
# 12817                  Borken_Kreis         Gronau_Westfalen
# 45619                       Potsdam         Nauener_Vorstadt
# 55314                 Görlitz_Kreis  Reichenbach/Oberlausitz
# 211789  Rendsburg_Eckernförde_Kreis                Rendsburg
#
#                                               description  \
# 12817   Die Wohnung befindet sich in einem Mehrfamilie...
# 45619   Die Stadtvilla wurde 2000 in Zusammenarbeit mi...
# 55314   Das Mehrfamilienhaus in der Thomas-Münzer-Stra...
# 211789  Angeboten wird eine helle 3-Zimmerwohnung in R...
#
#                                                facilities  heatingCosts  \
# 12817   Die Wohnung ist komplett mit PVC in Laminat-Op...           NaN
# 45619   Alle Zimmer sind mit Pitsch-Pine Holzdielen ve...         330.0
# 55314   Diese 6 Raum Wohnung ist eine Zusammenlegung v...         150.0
# 211789  Die Wohnung wird vollständig renoviert übergeben.          90.0
#
#        energyEfficiencyClass  lastRefurbish  electricityBasePrice  \
# 12817                      G            NaN                   NaN
# 45619                    NaN         2000.0                   NaN
# 55314                    NaN         2019.0                   NaN
# 211789        NO_INFORMATION            NaN                   NaN
#
#         electricityKwhPrice   date
# 12817                   NaN  Feb20
# 45619                   NaN  Feb20
# 55314                   NaN  Feb20
# 211789                  NaN  May19

# %%
state = data['regio1'].unique()
state
# Out:
# array(['Nordrhein_Westfalen', 'Rheinland_Pfalz', 'Sachsen', 'Bremen',
#        'Schleswig_Holstein', 'Baden_Württemberg', 'Thüringen', 'Hessen',
#        'Niedersachsen', 'Bayern', 'Hamburg', 'Sachsen_Anhalt',
#        'Mecklenburg_Vorpommern', 'Berlin', 'Brandenburg', 'Saarland'],
#       dtype=object)

# %%
data["yearConstructedRange"].value_counts(dropna=False)
# Out:
# NaN    57045
# 1.0    54203
# 2.0    45661
# 9.0    28685
# 5.0    26291
# 3.0    24262
# 4.0    18011
# 8.0     7578
# 6.0     3638
# 7.0     3476
# Name: yearConstructedRange, dtype: int64

# %%
data["condition"].value_counts(dropna=False)
# Out:
# NaN                                   68489
# well_kept                             66591
# refurbished                           26964
# fully_renovated                       26368
# first_time_use                        21959
# mint_condition                        21938
# modernized                            17226
# first_time_use_after_refurbishment    15699
# negotiable                             2240
# need_of_renovation                     1372
# ripe_for_demolition                       4
# Name: condition, dtype: int64

# %%
data["interiorQual"].value_counts(dropna=False)
# Out:
# NaN              112665
# normal            81826
# sophisticated     64762
# luxury             7648
# simple             1949
# Name: interiorQual, dtype: int64

# %%
pd.set_option('display.max_rows', 10)
data["street"].value_counts(dropna=False).head(10)
# Out:
# no_information            71013
# Hauptstra&szlig;e           936
# Bahnhofstra&szlig;e         853
# Leipziger Stra&szlig;e      440
# Goethestra&szlig;e          415
# Bahnhofstr.                 410
# Berliner Stra&szlig;e       381
# Schillerstra&szlig;e        378
# Gartenstra&szlig;e          360
# Schulstra&szlig;e           349
# Name: street, dtype: int64

# %%
data["streetPlain"].value_counts(dropna=False).head(10)
# Out:
# NaN                 71013
# Hauptstraße           911
# Bahnhofstraße         834
# Leipziger_Straße      428
# Goethestraße          406
# Bahnhofstr.           401
# Berliner_Straße       370
# Schillerstraße        363
# Gartenstraße          350
# Hauptstr.             334
# Name: streetPlain, dtype: int64

# %%
data["baseRentRange"].value_counts(dropna=False).head(10)
# Out:
# 2    54546
# 1    48225
# 5    38000
# 3    37138
# 7    27495
# 4    25808
# 6    24210
# 8     8251
# 9     5177
# Name: baseRentRange, dtype: int64

# %%
data["typeOfFlat"].value_counts(dropna=False).head(10)
# Out:
# apartment              131522
# NaN                     36614
# roof_storey             34787
# ground_floor            31538
# other                    9519
# maisonette               9319
# raised_ground_floor      5628
# penthouse                3568
# terraced_flat            3385
# half_basement            2013
# Name: typeOfFlat, dtype: int64

# %%
data["thermalChar"].value_counts(dropna=False).head(10)
# Out:
# NaN      106506
# 105.0       932
# 100.0       913
# 114.0       876
# 80.0        871
# 87.0        863
# 79.0        859
# 90.0        850
# 85.0        846
# 96.0        841
# Name: thermalChar, dtype: int64

# %%
data["floor"].value_counts(dropna=False).head(10)
# Out:
# 1.0    64133
# 2.0    56937
# NaN    51309
# 3.0    37879
# 0.0    24604
# 4.0    19953
# 5.0     7987
# 6.0     2493
# 7.0     1031
# 8.0      578
# Name: floor, dtype: int64

# %%
data["noRoomsRange"].value_counts(dropna=False).head(10)
# Out:
# 3    100992
# 2     98728
# 1     31218
# 4     29851
# 5      8061
# Name: noRoomsRange, dtype: int64

# %%
data["livingSpaceRange"].value_counts(dropna=False).head(10)
# Out:
# 3    82458
# 2    76383
# 4    42789
# 1    27057
# 5    20523
# 6    12866
# 7     6774
# Name: livingSpaceRange, dtype: int64

# %%
data["regio2"].value_counts(dropna=False)
# Out:
# Leipzig                         13723
# Chemnitz                        12575
# Berlin                          10406
# Dresden                          7522
# Magdeburg                        4860
#                                 ...
# Lichtenfels_Kreis                  31
# Freyung_Grafenau_Kreis             30
# Haßberge_Kreis                     24
# Neustadt_a.d._Waldnaab_Kreis       16
# Kronach_Kreis                      12
# Name: regio2, Length: 419, dtype: int64

# %%
data["regio3"].value_counts(dropna=False).head(10)
# Out:
# Innenstadt        4751
# Stadtmitte        2697
# Altstadt          2334
# Sonnenberg        1913
# Kaßberg           1712
# Mitte             1611
# Hilbersdorf       1297
# Schloßchemnitz    1266
# Zentrum           1135
# Südstadt          1117
# Name: regio3, dtype: int64

# %%
data["facilities"].value_counts(dropna=False).head(10)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           52924
# Laminat                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         207
# Diese Wohnung wird komplett renoviert und nach Bedarf mit neuen Fußbodenbelägen, Innentüren etc. ausgestattet. Das Bad ist gefliest und wird mit Badewanne bzw. Dusche ausgestattet. \rDiese Wohnung verfügt über eine moderne Ausstattung. Hierzu gehören die Gegensprechanlage, Kabel-, Internet- und Telefonanschluss ebenso, wie der Waschmaschinen- und Geschirrspüleranschluss.\rIndividuelle Ausstattungswünsche werden gern nach Möglichkeit und in Absprache mit unseren Mitarbeitern berücksichtigt. Die Wohnung wird vor Übergabe komplett gereinigt und ist sofort bezugsfertig.\rAbstellmöglichkeiten bietet der mietereigene Keller. Darüber hinaus steht unseren Mietern ein Wäschetrockenplatz zur Verfügung.\rKostenlose öffentliche Parkplätze sind in unmittelbarer Umgebung vorhanden.      183
# Laminatboden                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    107
# Einbauküche                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     104
# Parkett                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          89
# Fußbodenheizung                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  80
# Die Ausstattungsdetails finden Sie in der Objektbeschreibung bzw. im Detail in den Wohnungsgrundrissen.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          79
# Laminat, Fliesen                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 70
# Bad mit Wanne, Balkon /Loggia, Fernwärme, Fliesen Bad, Fliesen Küche, WC                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         70
# Name: facilities, dtype: int64

# %%
data["heatingCosts"].value_counts(dropna=False).head(10)
# Out:
# NaN      183332
# 60.0       5310
# 70.0       4811
# 80.0       4763
# 50.0       4286
# 100.0      3970
# 90.0       3015
# 0.0        2754
# 75.0       2601
# 65.0       2588
# Name: heatingCosts, dtype: int64

# %%
data["energyEfficiencyClass"].value_counts(dropna=False).head(20)
# Out:
# NaN               191063
# C                  14613
# NO_INFORMATION     14130
# D                  13925
# B                  11333
#                    ...
# A                   4988
# F                   4484
# A_PLUS              3618
# G                   1806
# H                    903
# Name: energyEfficiencyClass, Length: 11, dtype: int64

# %%
data["electricityBasePrice"].value_counts(dropna=False).head(20)
# Out:
# NaN      222004
# 90.76     42856
# 71.43      3990
# Name: electricityBasePrice, dtype: int64

# %%
data["electricityKwhPrice"].value_counts(dropna=False).head(20)
# Out:
# NaN       222004
# 0.1985     14639
# 0.2055     13076
# 0.1915     10114
# 0.1845      2952
#            ...
# 0.2132       404
# 0.2144       358
# 0.1705       240
# 0.2195       239
# 0.2265       193
# Name: electricityKwhPrice, Length: 16, dtype: int64

# %%
data.shape
# Out:
# (268850, 49)
