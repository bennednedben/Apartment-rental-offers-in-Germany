# %%
# import libraries
import pandas as pd
import numpy as np
import re
from nltk.tokenize import word_tokenize
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk import FreqDist
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('immo.csv')
pd.set_option('display.max_columns', None)
data.head(1)
# Out:
#    Unnamed: 0               regio1  serviceCharge      heatingType  \
# 0           0  Nordrhein_Westfalen          245.0  central_heating
#
#   telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0  ONE_YEAR_FREE                       0.0       False    False             6
#
#    pricetrend  telekomUploadSpeed  totalRent  yearConstructed   scoutId  \
# 0        4.62                10.0      840.0           1965.0  96107057
#
#    noParkSpaces firingTypes  hasKitchen              geo_bln  cellar  \
# 0           1.0         oil       False  Nordrhein_Westfalen    True
#
#    yearConstructedRange  baseRent houseNumber  livingSpace   geo_krs  \
# 0                   2.0     595.0         244         86.0  Dortmund
#
#    condition interiorQual petsAllowed                      street  \
# 0  well_kept       normal     unknown  Sch&uuml;ruferstra&szlig;e
#
#        streetPlain   lift  baseRentRange    typeOfFlat  geo_plz  noRooms  \
# 0  Schüruferstraße  False              4  ground_floor    44269      4.0
#
#    thermalChar  floor  numberOfFloors  noRoomsRange  garden  livingSpaceRange  \
# 0        181.4    1.0             3.0             4    True                 4
#
#      regio2   regio3                                        description  \
# 0  Dortmund  Schüren  Die ebenerdig zu erreichende Erdgeschosswohnun...
#
#                                           facilities  heatingCosts  \
# 0  Die Wohnung ist mit Laminat ausgelegt. Das Bad...        77.111
#
#   energyEfficiencyClass  lastRefurbish  electricityBasePrice  \
# 0               unknown         2009.1                 89.11
#
#    electricityKwhPrice   date  Euro/m2  price_class
# 0              0.21111  May19     6.92            4

# %%
def clean_up(s):
    """
    Cleans up numbers, URLs, and special characters from a string.

    Args:
        s: The string to be cleaned up.

    Returns:
        A string that has been cleaned up.
    """
    s = s.lower()
    s = s.replace('@', '')
    s = s.replace('#', '')
    # s = s.replace('http://', '')
    s = re.sub(r'http\S+', '', s)
    # s = re.sub(r'www\S+', '', s)
    s = re.sub(r'\d+', '', s)
    s = s.replace('[', '')
    s = s.replace('(', '')
    s = s.replace(')', '')
    s = s.replace(']', '')
    s = s.replace("'", ' ')
    s = s.replace("-", ' ')
    
    return s

# %%
def tokenize(s):
    """
    Tokenize a string.

    Args:
        s: String to be tokenized.

    Returns:
        A list of words as the result of tokenization.
    """
    tokens = word_tokenize(s)
    words = [word.lower() for word in tokens if word.isalnum()]

    return words

# %%
def stem_and_lemmatize(l):
    por_ste = PorterStemmer()
    stemmer = [por_ste.stem(w) for w in l]
    lemmatizer = WordNetLemmatizer() 
    lemmatizing = [lemmatizer.lemmatize(word) for word in l]
    
    return stemmer, lemmatizing

# %%
stop_words = set(stopwords.words('german'))
def remove_stopwords_tokens(l):
    """
    Remove German stopwords from a list of strings.

    Args:
        l: A list of strings.

    Returns:
        A list of strings after stop words are removed.
    """
    filtered_words = [w for w in l if w.lower() not in stop_words]

        
    return filtered_words

# %%
stop_words = set(stopwords.words('german'))
def remove_stopwords_text(l):
    """
    Remove German stopwords from a list of strings.

    Args:
        l: A list of strings.

    Returns:
        A list of strings after stop words are removed.
    """
    cleaned_list = []
    for text in l:
        words = text.split()
        filtered_words = [w for w in words if w.lower() not in stop_words]
        cleaned_list.append(' '.join(filtered_words))
        
    return cleaned_list

# %%
#test
l = ['Nordkorea hat nach Angaben des südkoreanischen Militärs eine atomwaffenfähige Rakete mit einer Reichweite von möglicherweise tausenden Kilometern in Richtung offenes Meer abgefeuert. Der Start sei am Donnerstagmorgen (Ortszeit) in der Nähe der nordkoreanischen Hauptstadt Pjöngjang erfolgt, teilte der Generalstab in Seoul mit. Die Rakete sei dann in Richtung Japanisches Meer (koreanisch: Ostmeer) geflogen.']
cleaned_list = remove_stopwords_text(l)
print(cleaned_list)
# Out:
# ['Nordkorea Angaben südkoreanischen Militärs atomwaffenfähige Rakete Reichweite möglicherweise tausenden Kilometern Richtung offenes Meer abgefeuert. Start sei Donnerstagmorgen (Ortszeit) Nähe nordkoreanischen Hauptstadt Pjöngjang erfolgt, teilte Generalstab Seoul mit. Rakete sei Richtung Japanisches Meer (koreanisch: Ostmeer) geflogen.']

# %%
data['cleaned_up'] = data['description'].apply(clean_up)
data['tokenized'] = data['cleaned_up'].apply(tokenize)
data['stemmed'], data['lemmatized'] = zip(*data['tokenized'].apply(stem_and_lemmatize))
data['text_processed'] = data['tokenized'].apply(remove_stopwords_tokens)
data
# Out:
#         Unnamed: 0               regio1  serviceCharge  \
# 0                0  Nordrhein_Westfalen         245.00
# 1                1      Rheinland_Pfalz         134.00
# 2                2              Sachsen         255.00
# 3                3              Sachsen          58.15
# 4                4               Bremen         138.00
# ...            ...                  ...            ...
# 267805      268845               Bayern          90.00
# 267806      268846               Hessen         220.00
# 267807      268847               Hessen         220.00
# 267808      268848  Nordrhein_Westfalen         175.00
# 267809      268849               Hessen         315.00
#
#                            heatingType telekomTvOffer  \
# 0                      central_heating  ONE_YEAR_FREE
# 1       self_contained_central_heating  ONE_YEAR_FREE
# 2                        floor_heating  ONE_YEAR_FREE
# 3                     district_heating  ONE_YEAR_FREE
# 4       self_contained_central_heating        unknown
# ...                                ...            ...
# 267805                       heat_pump  ONE_YEAR_FREE
# 267806                     gas_heating        unknown
# 267807                 central_heating  ONE_YEAR_FREE
# 267808                       heat_pump        unknown
# 267809                 central_heating        unknown
#
#         telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0                            0.0       False    False             6
# 1                            0.0       False     True             8
# 2                           10.0        True     True             8
# 3                            0.0       False     True             9
# 4                            0.0       False     True            19
# ...                          ...         ...      ...           ...
# 267805                       0.0       False     True             0
# 267806                       0.0       False     True            12
# 267807                       0.0       False     True            21
# 267808                       0.0        True     True            16
# 267809                       0.0       False     True             9
#
#         pricetrend  telekomUploadSpeed  totalRent  yearConstructed    scoutId  \
# 0             4.62                10.0     840.00           1965.0   96107057
# 1             3.47                10.0     814.11           1871.0  111378734
# 2             2.72                 2.4    1300.00           2019.0  113147523
# 3             1.53                40.0     814.11           1964.0  108890903
# 4             2.46                40.0     903.00           1950.0  114751222
# ...            ...                 ...        ...              ...        ...
# 267805        2.74                10.0     910.00           2016.0  115641081
# 267806        6.49                40.0    1150.00           1983.0   96981497
# 267807        2.90                40.0     930.00           1965.0   66924271
# 267808        4.39                40.0    1015.00           2019.0  110938302
# 267809        5.00                40.0     814.11           1972.0  115524054
#
#         noParkSpaces       firingTypes  hasKitchen              geo_bln  \
# 0                1.0               oil       False  Nordrhein_Westfalen
# 1                2.0               gas       False      Rheinland_Pfalz
# 2                1.0           unknown       False              Sachsen
# 3                0.0  district_heating       False              Sachsen
# 4                0.0               gas       False               Bremen
# ...              ...               ...         ...                  ...
# 267805           1.0        geothermal       False               Bayern
# 267806           1.0               gas        True               Hessen
# 267807           1.0               gas       False               Hessen
# 267808           1.0               gas       False  Nordrhein_Westfalen
# 267809           1.0  district_heating        True               Hessen
#
#         cellar  yearConstructedRange  baseRent houseNumber  livingSpace  \
# 0         True                   2.0     595.0         244        86.00
# 1        False                   1.0     800.0           1        89.00
# 2         True                   9.0     965.0           4        83.80
# 3        False                   2.0     343.0          35        58.15
# 4        False                   1.0     765.0          10        84.97
# ...        ...                   ...       ...         ...          ...
# 267805    True                   9.0     820.0           1        90.00
# 267806   False                   4.0     930.0           1       115.00
# 267807    True                   2.0     650.0          10        95.00
# 267808    True                   9.0     840.0          58        70.00
# 267809    True                   3.0     935.0           8        77.00
#
#                         geo_krs       condition   interiorQual petsAllowed  \
# 0                      Dortmund       well_kept         normal     unknown
# 1             Rhein_Pfalz_Kreis     refurbished         normal          no
# 2                       Dresden  first_time_use  sophisticated     unknown
# 3           Mittelsachsen_Kreis         unknown        unknown     unknown
# 4                        Bremen     refurbished        unknown     unknown
# ...                         ...             ...            ...         ...
# 267805  Weilheim_Schongau_Kreis  mint_condition  sophisticated          no
# 267806         Bergstraße_Kreis       well_kept  sophisticated  negotiable
# 267807   Limburg_Weilburg_Kreis       well_kept        unknown  negotiable
# 267808                     Köln  first_time_use  sophisticated          no
# 267809        Frankfurt_am_Main      modernized        unknown     unknown
#
#                              street                  streetPlain   lift  \
# 0        Sch&uuml;ruferstra&szlig;e              Schüruferstraße  False
# 1                    no_information                      unknown  False
# 2                         Turnerweg                    Turnerweg   True
# 3       Gl&uuml;ck-Auf-Stra&szlig;e             Glück-Auf-Straße  False
# 4       Hermann-Henrich-Meier-Allee  Hermann-Henrich-Meier-Allee  False
# ...                             ...                          ...    ...
# 267805               no_information                      unknown  False
# 267806               no_information                      unknown  False
# 267807               Emsbachstrasse               Emsbachstrasse  False
# 267808              Idastra&szlig;e                    Idastraße   True
# 267809    Robert-Di&szlig;mann-Str.          Robert-Dißmann-Str.   True
#
#         baseRentRange    typeOfFlat  geo_plz  noRooms  thermalChar  floor  \
# 0                   4  ground_floor    44269      4.0       181.40    1.0
# 1                   5  ground_floor    67459      3.0       114.11    2.1
# 2                   6     apartment     1097      3.0       114.11    3.0
# 3                   2         other     9599      3.0        86.00    3.0
# 4                   5     apartment    28213      3.0       188.90    1.0
# ...               ...           ...      ...      ...          ...    ...
# 267805              6   roof_storey    82390      3.0       114.11    2.1
# 267806              6     apartment    68519      3.5       114.11    1.0
# 267807              5     apartment    65552      4.0       160.77    1.0
# 267808              6     apartment    51069      2.0        24.70    2.1
# 267809              6     apartment    65936      3.0       114.11    2.1
#
#         numberOfFloors  noRoomsRange  garden  livingSpaceRange  \
# 0                  3.0             4    True                 4
# 1                  3.1             3   False                 4
# 2                  4.0             3   False                 4
# 3                  3.1             3   False                 2
# 4                  3.1             3   False                 4
# ...                ...           ...     ...               ...
# 267805             3.1             3   False                 4
# 267806             1.0             3   False                 5
# 267807             2.0             4    True                 4
# 267808             5.0             2   False                 3
# 267809            13.0             3   False                 3
#
#                          regio2                      regio3  \
# 0                      Dortmund                     Schüren
# 1             Rhein_Pfalz_Kreis              Böhl_Iggelheim
# 2                       Dresden  Äußere_Neustadt_Antonstadt
# 3           Mittelsachsen_Kreis                    Freiberg
# 4                        Bremen           Neu_Schwachhausen
# ...                         ...                         ...
# 267805  Weilheim_Schongau_Kreis                    Eberfing
# 267806         Bergstraße_Kreis                   Viernheim
# 267807   Limburg_Weilburg_Kreis         Limburg_an_der_Lahn
# 267808                     Köln                   Dellbrück
# 267809        Frankfurt_am_Main                  Sossenheim
#
#                                               description  \
# 0       Die ebenerdig zu erreichende Erdgeschosswohnun...
# 1       Alles neu macht der Mai – so kann es auch für ...
# 2       Der Neubau entsteht im Herzen der Dresdner Neu...
# 3       Abseits von Lärm und Abgasen in Ihre neue Wohn...
# 4       Es handelt sich hier um ein saniertes Mehrfami...
# ...                                                   ...
# 267805  Diese schöne, neuwertige Wohnung im Dachgescho...
# 267806  Hier wird eine Wohnung im 2 Familienhaus angeb...
# 267807  gemütliche 4-Zimmer-Wohnung im Obergeschoss ei...
# 267808  Neubau Erstbezug, gehobener Standard, alle Ein...
# 267809  Schöne, helle, gut geschnittene und teilmöblie...
#
#                                                facilities  heatingCosts  \
# 0       Die Wohnung ist mit Laminat ausgelegt. Das Bad...        77.111
# 1                                                 unknown        77.111
# 2       * 9 m² Balkon\n* Bad mit bodengleicher Dusche,...        77.111
# 3                                                 unknown        87.230
# 4       Diese Wohnung wurde neu saniert und ist wie fo...        77.111
# ...                                                   ...           ...
# 267805         Fliesen und Parkett. Sichtbarer Dachstuhl.        77.111
# 267806  Parkett, Kamin, Badewanne&Dusche\nGroßer Balko...        77.111
# 267807  Böden: Wohn-/Schlafbereich = Laminat, Küche + ...        77.111
# 267808  Wände:\nMaler­vlies, weiß gestrichen alter­nat...        40.000
# 267809  Balkon, Keller, Fahrstuhl, Vollbad, Einbauküch...        77.111
#
#        energyEfficiencyClass  lastRefurbish  electricityBasePrice  \
# 0                    unknown         2009.1                 89.11
# 1                    unknown         2019.0                 89.11
# 2                    unknown         2009.1                 89.11
# 3                    unknown         2009.1                 89.11
# 4                    unknown         2009.1                 89.11
# ...                      ...            ...                   ...
# 267805               unknown         2009.1                 89.11
# 267806               unknown         2015.0                 89.11
# 267807               unknown         2019.0                 89.11
# 267808               unknown         2019.0                 89.11
# 267809               unknown         2009.1                 89.11
#
#         electricityKwhPrice   date  Euro/m2  price_class  \
# 0                   0.21111  May19     6.92            4
# 1                   0.21111  May19     8.99            6
# 2                   0.21111  Oct19    11.52            8
# 3                   0.21111  May19     5.90            3
# 4                   0.21111  Feb20     9.00            6
# ...                     ...    ...      ...          ...
# 267805              0.21111  Feb20     9.11            7
# 267806              0.21111  May19     8.09            6
# 267807              0.21111  Feb20     6.84            4
# 267808              0.21111  May19    12.00            8
# 267809              0.21111  Feb20    12.14            9
#
#                                                cleaned_up  \
# 0       die ebenerdig zu erreichende erdgeschosswohnun...
# 1       alles neu macht der mai – so kann es auch für ...
# 2       der neubau entsteht im herzen der dresdner neu...
# 3       abseits von lärm und abgasen in ihre neue wohn...
# 4       es handelt sich hier um ein saniertes mehrfami...
# ...                                                   ...
# 267805  diese schöne, neuwertige wohnung im dachgescho...
# 267806  hier wird eine wohnung im  familienhaus angebo...
# 267807  gemütliche  zimmer wohnung im obergeschoss ein...
# 267808  neubau erstbezug, gehobener standard, alle ein...
# 267809  schöne, helle, gut geschnittene und teilmöblie...
#
#                                                 tokenized  \
# 0       [die, ebenerdig, zu, erreichende, erdgeschossw...
# 1       [alles, neu, macht, der, mai, so, kann, es, au...
# 2       [der, neubau, entsteht, im, herzen, der, dresd...
# 3       [abseits, von, lärm, und, abgasen, in, ihre, n...
# 4       [es, handelt, sich, hier, um, ein, saniertes, ...
# ...                                                   ...
# 267805  [diese, schöne, neuwertige, wohnung, im, dachg...
# 267806  [hier, wird, eine, wohnung, im, familienhaus, ...
# 267807  [gemütliche, zimmer, wohnung, im, obergeschoss...
# 267808  [neubau, erstbezug, gehobener, standard, alle,...
# 267809  [schöne, helle, gut, geschnittene, und, teilmö...
#
#                                                   stemmed  \
# 0       [die, ebenerdig, zu, erreichend, erdgeschosswo...
# 1       [all, neu, macht, der, mai, so, kann, es, auch...
# 2       [der, neubau, entsteht, im, herzen, der, dresd...
# 3       [abseit, von, lärm, und, abgasen, in, ihr, neu...
# 4       [es, handelt, sich, hier, um, ein, saniert, me...
# ...                                                   ...
# 267805  [dies, schöne, neuwertig, wohnung, im, dachges...
# 267806  [hier, wird, ein, wohnung, im, familienhau, an...
# 267807  [gemütlich, zimmer, wohnung, im, obergeschoss,...
# 267808  [neubau, erstbezug, gehoben, standard, all, ei...
# 267809  [schöne, hell, gut, geschnitten, und, teilmöbl...
#
#                                                lemmatized  \
# 0       [die, ebenerdig, zu, erreichende, erdgeschossw...
# 1       [alles, neu, macht, der, mai, so, kann, e, auc...
# 2       [der, neubau, entsteht, im, herzen, der, dresd...
# 3       [abseits, von, lärm, und, abgasen, in, ihre, n...
# 4       [e, handelt, sich, hier, um, ein, saniertes, m...
# ...                                                   ...
# 267805  [diese, schöne, neuwertige, wohnung, im, dachg...
# 267806  [hier, wird, eine, wohnung, im, familienhaus, ...
# 267807  [gemütliche, zimmer, wohnung, im, obergeschoss...
# 267808  [neubau, erstbezug, gehobener, standard, alle,...
# 267809  [schöne, helle, gut, geschnittene, und, teilmö...
#
#                                            text_processed
# 0       [ebenerdig, erreichende, erdgeschosswohnung, b...
# 1       [neu, macht, mai, genießen, reine, gefühl, unb...
# 2       [neubau, entsteht, herzen, dresdner, neustadt,...
# 3       [abseits, lärm, abgasen, neue, wohnung, stress...
# 4            [handelt, saniertes, mehrfamilienhaus, jahr]
# ...                                                   ...
# 267805  [schöne, neuwertige, wohnung, dachgeschoss, ze...
# 267806  [wohnung, familienhaus, angeboten, wohung, lie...
# 267807  [gemütliche, zimmer, wohnung, obergeschoss, fa...
# 267808  [neubau, erstbezug, gehobener, standard, einhe...
# 267809  [schöne, helle, gut, geschnittene, teilmöblier...
#
# [267810 rows x 57 columns]

# %%
words = [' '.join(words) for words in data['text_processed']]

vector = CountVectorizer(max_features=500)

X = vector.fit_transform(words)

count = np.asarray(X.sum(axis=0)).ravel()

feature_names = vector.get_feature_names()

dict = dict(zip(feature_names, count))

dist = FreqDist(dict)

dist.most_common(100)
#list the 100 most common words in data['description'] (without stop words)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# [('wohnung', 310274),
#  ('befindet', 100327),
#  ('zimmer', 91854),
#  ('küche', 80223),
#  ('sowie', 77526),
#  ('balkon', 67956),
#  ('verfügt', 56630),
#  ('bad', 55901),
#  ('schlafzimmer', 50899),
#  ('wurde', 50776),
#  ('ca', 48974),
#  ('haus', 47277),
#  ('m²', 46874),
#  ('wohnzimmer', 45393),
#  ('ausgestattet', 44747),
#  ('wohnungen', 43678),
#  ('liegt', 42752),
#  ('verfügung', 41551),
#  ('einbauküche', 41032),
#  ('objekt', 40147),
#  ('badezimmer', 38403),
#  ('bietet', 36809),
#  ('dusche', 36118),
#  ('zwei', 35904),
#  ('wc', 35096),
#  ('wohn', 34411),
#  ('ab', 33280),
#  ('mehrfamilienhaus', 32264),
#  ('kellerraum', 32137),
#  ('fenster', 31780),
#  ('lage', 30204),
#  ('große', 29325),
#  ('stellplatz', 29122),
#  ('schöne', 28861),
#  ('flur', 27983),
#  ('vorhanden', 27218),
#  ('helle', 26809),
#  ('gepflegten', 26585),
#  ('steht', 26066),
#  ('stehen', 25467),
#  ('gehört', 25112),
#  ('direkt', 24598),
#  ('handelt', 24258),
#  ('erreichen', 24233),
#  ('obergeschoss', 24203),
#  ('großen', 23573),
#  ('badewanne', 23216),
#  ('platz', 22855),
#  ('außerdem', 22030),
#  ('gäste', 21616),
#  ('raum', 21348),
#  ('abstellraum', 21234),
#  ('befinden', 21197),
#  ('keller', 21193),
#  ('mieter', 20976),
#  ('moderne', 20945),
#  ('garten', 20746),
#  ('etage', 20287),
#  ('terrasse', 19890),
#  ('unknown', 19688),
#  ('qm', 19663),
#  ('zugang', 19661),
#  ('mehrfamilienhauses', 19556),
#  ('nähe', 19484),
#  ('wohnen', 18845),
#  ('komplett', 18687),
#  ('og', 18349),
#  ('neue', 18167),
#  ('neu', 18028),
#  ('blick', 17749),
#  ('ebenfalls', 17235),
#  ('gibt', 17129),
#  ('saniert', 17106),
#  ('gut', 17054),
#  ('bezogen', 16908),
#  ('großzügige', 16689),
#  ('lässt', 16618),
#  ('neben', 16462),
#  ('bitte', 16457),
#  ('erdgeschoss', 16408),
#  ('drei', 16397),
#  ('finden', 16302),
#  ('wohnfläche', 16255),
#  ('räume', 15936),
#  ('aufzug', 15752),
#  ('wanne', 15593),
#  ('diele', 15459),
#  ('wohnanlage', 15319),
#  ('ruhigen', 15175),
#  ('weitere', 15120),
#  ('ausstattung', 14978),
#  ('sofort', 14702),
#  ('gebäude', 14498),
#  ('dachgeschoss', 14393),
#  ('insgesamt', 14079),
#  ('immobilie', 13975),
#  ('jahr', 13907),
#  ('tageslichtbad', 13797),
#  ('pkw', 13641),
#  ('modernen', 13400)]

# %%
data.head()
# Out:
#    Unnamed: 0               regio1  serviceCharge  \
# 0           0  Nordrhein_Westfalen         245.00
# 1           1      Rheinland_Pfalz         134.00
# 2           2              Sachsen         255.00
# 3           3              Sachsen          58.15
# 4           4               Bremen         138.00
#
#                       heatingType telekomTvOffer  telekomHybridUploadSpeed  \
# 0                 central_heating  ONE_YEAR_FREE                       0.0
# 1  self_contained_central_heating  ONE_YEAR_FREE                       0.0
# 2                   floor_heating  ONE_YEAR_FREE                      10.0
# 3                district_heating  ONE_YEAR_FREE                       0.0
# 4  self_contained_central_heating        unknown                       0.0
#
#    newlyConst  balcony  picturecount  pricetrend  telekomUploadSpeed  \
# 0       False    False             6        4.62                10.0
# 1       False     True             8        3.47                10.0
# 2        True     True             8        2.72                 2.4
# 3       False     True             9        1.53                40.0
# 4       False     True            19        2.46                40.0
#
#    totalRent  yearConstructed    scoutId  noParkSpaces       firingTypes  \
# 0     840.00           1965.0   96107057           1.0               oil
# 1     814.11           1871.0  111378734           2.0               gas
# 2    1300.00           2019.0  113147523           1.0           unknown
# 3     814.11           1964.0  108890903           0.0  district_heating
# 4     903.00           1950.0  114751222           0.0               gas
#
#    hasKitchen              geo_bln  cellar  yearConstructedRange  baseRent  \
# 0       False  Nordrhein_Westfalen    True                   2.0     595.0
# 1       False      Rheinland_Pfalz   False                   1.0     800.0
# 2       False              Sachsen    True                   9.0     965.0
# 3       False              Sachsen   False                   2.0     343.0
# 4       False               Bremen   False                   1.0     765.0
#
#   houseNumber  livingSpace              geo_krs       condition  \
# 0         244        86.00             Dortmund       well_kept
# 1           1        89.00    Rhein_Pfalz_Kreis     refurbished
# 2           4        83.80              Dresden  first_time_use
# 3          35        58.15  Mittelsachsen_Kreis         unknown
# 4          10        84.97               Bremen     refurbished
#
#     interiorQual petsAllowed                       street  \
# 0         normal     unknown   Sch&uuml;ruferstra&szlig;e
# 1         normal          no               no_information
# 2  sophisticated     unknown                    Turnerweg
# 3        unknown     unknown  Gl&uuml;ck-Auf-Stra&szlig;e
# 4        unknown     unknown  Hermann-Henrich-Meier-Allee
#
#                    streetPlain   lift  baseRentRange    typeOfFlat  geo_plz  \
# 0              Schüruferstraße  False              4  ground_floor    44269
# 1                      unknown  False              5  ground_floor    67459
# 2                    Turnerweg   True              6     apartment     1097
# 3             Glück-Auf-Straße  False              2         other     9599
# 4  Hermann-Henrich-Meier-Allee  False              5     apartment    28213
#
#    noRooms  thermalChar  floor  numberOfFloors  noRoomsRange  garden  \
# 0      4.0       181.40    1.0             3.0             4    True
# 1      3.0       114.11    2.1             3.1             3   False
# 2      3.0       114.11    3.0             4.0             3   False
# 3      3.0        86.00    3.0             3.1             3   False
# 4      3.0       188.90    1.0             3.1             3   False
#
#    livingSpaceRange               regio2                      regio3  \
# 0                 4             Dortmund                     Schüren
# 1                 4    Rhein_Pfalz_Kreis              Böhl_Iggelheim
# 2                 4              Dresden  Äußere_Neustadt_Antonstadt
# 3                 2  Mittelsachsen_Kreis                    Freiberg
# 4                 4               Bremen           Neu_Schwachhausen
#
#                                          description  \
# 0  Die ebenerdig zu erreichende Erdgeschosswohnun...
# 1  Alles neu macht der Mai – so kann es auch für ...
# 2  Der Neubau entsteht im Herzen der Dresdner Neu...
# 3  Abseits von Lärm und Abgasen in Ihre neue Wohn...
# 4  Es handelt sich hier um ein saniertes Mehrfami...
#
#                                           facilities  heatingCosts  \
# 0  Die Wohnung ist mit Laminat ausgelegt. Das Bad...        77.111
# 1                                            unknown        77.111
# 2  * 9 m² Balkon\n* Bad mit bodengleicher Dusche,...        77.111
# 3                                            unknown        87.230
# 4  Diese Wohnung wurde neu saniert und ist wie fo...        77.111
#
#   energyEfficiencyClass  lastRefurbish  electricityBasePrice  \
# 0               unknown         2009.1                 89.11
# 1               unknown         2019.0                 89.11
# 2               unknown         2009.1                 89.11
# 3               unknown         2009.1                 89.11
# 4               unknown         2009.1                 89.11
#
#    electricityKwhPrice   date  Euro/m2  price_class  \
# 0              0.21111  May19     6.92            4
# 1              0.21111  May19     8.99            6
# 2              0.21111  Oct19    11.52            8
# 3              0.21111  May19     5.90            3
# 4              0.21111  Feb20     9.00            6
#
#                                           cleaned_up  \
# 0  die ebenerdig zu erreichende erdgeschosswohnun...
# 1  alles neu macht der mai – so kann es auch für ...
# 2  der neubau entsteht im herzen der dresdner neu...
# 3  abseits von lärm und abgasen in ihre neue wohn...
# 4  es handelt sich hier um ein saniertes mehrfami...
#
#                                            tokenized  \
# 0  [die, ebenerdig, zu, erreichende, erdgeschossw...
# 1  [alles, neu, macht, der, mai, so, kann, es, au...
# 2  [der, neubau, entsteht, im, herzen, der, dresd...
# 3  [abseits, von, lärm, und, abgasen, in, ihre, n...
# 4  [es, handelt, sich, hier, um, ein, saniertes, ...
#
#                                              stemmed  \
# 0  [die, ebenerdig, zu, erreichend, erdgeschosswo...
# 1  [all, neu, macht, der, mai, so, kann, es, auch...
# 2  [der, neubau, entsteht, im, herzen, der, dresd...
# 3  [abseit, von, lärm, und, abgasen, in, ihr, neu...
# 4  [es, handelt, sich, hier, um, ein, saniert, me...
#
#                                           lemmatized  \
# 0  [die, ebenerdig, zu, erreichende, erdgeschossw...
# 1  [alles, neu, macht, der, mai, so, kann, e, auc...
# 2  [der, neubau, entsteht, im, herzen, der, dresd...
# 3  [abseits, von, lärm, und, abgasen, in, ihre, n...
# 4  [e, handelt, sich, hier, um, ein, saniertes, m...
#
#                                       text_processed
# 0  [ebenerdig, erreichende, erdgeschosswohnung, b...
# 1  [neu, macht, mai, genießen, reine, gefühl, unb...
# 2  [neubau, entsteht, herzen, dresdner, neustadt,...
# 3  [abseits, lärm, abgasen, neue, wohnung, stress...
# 4       [handelt, saniertes, mehrfamilienhaus, jahr]

# %%
data['Euro/m2'].mean()
# Out:
# 8.702651730705037

# %%
data2 = data[data['cleaned_up'].str.contains('einbauküche', case=False)]
data2['Euro/m2'].mean()
# Out:
# 10.765424984462392
